# %%
# Team NASA - CS 6330 - Spring Semester 2024

# %% [markdown]
# # **Cover**

# %% [markdown]
# **Section #1: Identify - Caden**

# %% [markdown]
# We will use problem solving and analysis to determine whether or not each column, or feature, in the dataset is numerical or categorical. This will help us understand our dataset and results at a deeper level when analyzing and manipulation the data.

# %%
'''
Numerical Features:
1. tree_depth
2. part_number
3. serial_number
4. status
5. system
6. subsystem
7. action_date
8. move_dat
9. categoryID

Categorical Features:
1. datedim
2. id
3. id_parent
4. id_path
5. location_name
6. original_ip_owner
7. state
8. is_container
9. is_moveable
10. fill_status
11. category_name
'''
# Out:
# '\nNumerical Features:\n1. tree_depth\n2. part_number\n3. serial_number\n4. status\n5. system\n6. subsystem\n7. action_date\n8. move_dat\n9. categoryID\n\nCategorical Features:\n1. datedim\n2. id\n3. id_parent\n4. id_path\n5. location_name\n6. original_ip_owner\n7. state\n8. is_container\n9. is_moveable\n10. fill_status\n11. category_name\n'

# %% [markdown]
# We recognized the numerical features by identifying whether the features represents numerical values, can be subject to arithmetic operations, or includes measurements in quantities. We recognized the categorical features by identifying whether the feature represented categories or labels, cannot be subject to arithmetic operations, and classifies certain parts of the data. With these results, we can better understand our dataset for subsequent steps.

# %% [markdown]
# **Section #2: Single Feature Plots - Caden**

# %% [markdown]
# We will show examples of Seaborn single feature plots and how they interact with the Barrios dataset. This will give us a better understand of single feature plots and how they can be used to our advantage.

# %%
# Mounting the drive for access to data
import os
from google.colab import drive
drive.mount('/content/drive/')
flist = os.listdir('drive/MyDrive/Barrios-ASU - ISS Consumables Data Package/csv')

# Outputs the first CSV file in the Barrios folder
import pandas as pd
dir = 'drive/MyDrive/Barrios-ASU - ISS Consumables Data Package/csv/'
df = pd.read_csv(dir + flist[0])

# Uses histplot method
import seaborn as sns
sns.histplot(df, x='tree_depth')
# Out:
# Mounted at /content/drive/
# <Axes: xlabel='tree_depth', ylabel='Count'>

# %%
df.head()
# Out:
#           datedim      id  id_parent             id_path  tree_depth  \
# 0  1/1/2022 10:01  364155        265  /0/101/265/364155/           3
# 1  1/1/2022 10:01  364156        265  /0/101/265/364156/           3
# 2  1/1/2022 10:01  364157        265  /0/101/265/364157/           3
# 3  1/1/2022 10:01  364158        265  /0/101/265/364158/           3
# 4  1/1/2022 10:01  364160        265  /0/101/265/364160/           3
#
#                tree        part_number serial_number location_name  \
# 0  Storage Location  11Ф615.8720А55-20          1180        ФГБ1ГА
# 1  Storage Location  11Ф615.8720А55-20          1181        ФГБ1ГА
# 2  Storage Location  11Ф615.8720А55-20          1182        ФГБ1ГА
# 3  Storage Location  11Ф615.8720А55-10          1182        ФГБ1ГА
# 4  Storage Location  11Ф615.8720А55-20          1184        ФГБ1ГА
#
#       original_ip_owner  ...  status is_container is_moveable  \
# 0  Russian Space Agency  ...  Stowed            1           1
# 1  Russian Space Agency  ...  Stowed            1           1
# 2  Russian Space Agency  ...  Stowed            1           1
# 3  Russian Space Agency  ...  Stowed            1           1
# 4  Russian Space Agency  ...  Stowed            1           1
#
#                           system subsystem       action_date  \
# 0  SM Hygiene Sanitary Equipment      АсСУ  10/10/2020 19:22
# 1  SM Hygiene Sanitary Equipment      АсСУ  10/10/2020 19:22
# 2  SM Hygiene Sanitary Equipment      АсСУ  10/10/2020 19:22
# 3  SM Hygiene Sanitary Equipment      АсСУ  10/10/2020 19:22
# 4  SM Hygiene Sanitary Equipment      АсСУ  10/10/2020 19:22
#
#           move_date  fill_status  categoryID  category_name
# 0  10/10/2020 19:22          NaN           3            KTO
# 1  10/10/2020 19:22          NaN           3            KTO
# 2  10/10/2020 19:22          NaN           3            KTO
# 3  10/10/2020 19:22          NaN           3            KTO
# 4  10/10/2020 19:22          NaN           3            KTO
#
# [5 rows x 41 columns]

# %% [markdown]
# The hisplot() method displays a histogram of the tree_depth feature. Visually, it appears to show straight lines to demonstrate the count of each tree_depth from the dataset.

# %%
# Uses kdeplot method
sns.kdeplot(df, x='tree_depth')
# Out:
# <Axes: xlabel='tree_depth', ylabel='Density'>

# %% [markdown]
# The kdeplot() method visualizes our data using a density plot of the tree_depth feature. This appears to be similar to the histplot, but using a different metric, density, and having a different shape to the lines.

# %%
# Uses countplot method
sns.countplot(df, x='is_moveable')
# Out:
# <Axes: xlabel='is_moveable', ylabel='count'>

# %% [markdown]
# The countplot() method creates a bar chart from the is_moveable categorical feature rather than a numerical feature. It seems to have created only one bar for a large count.

# %%
# Uses boxplot method
sns.boxplot(df, x='tree_depth')
# Out:
# <Axes: xlabel='tree_depth'>

# %% [markdown]
# The boxplot() method seems to only use the x-axis and simply creates a box plot from the tree_depth numerical feature from the dataset.

# %%
# Uses violinplot method
sns.violinplot(df, x='tree_depth')
# Out:
# <Axes: xlabel='tree_depth'>

# %% [markdown]
# Similar to the boxplot() method, the violinplot() method uses only the x-axis in its graphing. It appears to create a violin plot based on the tree_depth numerical feature within the dataset.

# %% [markdown]
# Through using and exploring each single feature plot using Seaborn and its multiple methods, we were able to visualize our data in multiple new ways. This allows for easier analysis and business intelligence of our data and provides us with multiple options for visualizing both numerical and categorical features in different ways.

# %% [markdown]
# **Section #3: Two Feature Plots - Taylor/Caden**

# %% [markdown]
# In order to complement our plots above, using scatterplots and stripplots we are able to see both the relationship between two variables as well as the distribution. Using the style and hue parameters, we are able to add another feature to compare.

# %%
# Using a Scatterplot
sns.scatterplot(df, x='tree_depth', y='id', style='status')
# Out:
# <Axes: xlabel='tree_depth', ylabel='id'>

# %% [markdown]
# Using a scatterplot creates a graph with structured, scattered lines comprised of circles, squarts, and exes to represent the status of the tree_depth.

# %%
# Using a Swarmplot
sns.swarmplot(df, x='tree_depth', y='id', size=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a7d7d2f6d4d1> in <cell line: 2>()
#       1 # Using a Swarmplot
# ----> 2 sns.swarmplot(df, x='tree_depth', y='id', size=2)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2247     ))
#    2248
# -> 2249     p.plot_swarms(
#    2250         dodge=dodge,
#    2251         color=color,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     585                 points.draw = draw.__get__(points)
#     586
# --> 587         _draw_figure(ax.figure)
#     588         self._configure_legend(ax, _scatter_legend_artist, plot_kws)
#     589
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in _draw_figure(fig)
#      59     """Force draw of a matplotlib figure, accounting for back-compat."""
#      60     # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 61     fig.canvas.draw()
#      62     if fig.stale:
#      63         try:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in draw(points, renderer, center)
#     563                 def draw(points, renderer, *, center=center):
#     564
# --> 565                     beeswarm(points, center)
#     566
#     567                     if self.orient == "y":
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __call__(self, points, center)
#    3260         # Adjust points along the categorical axis to prevent overlaps
#    3261         new_xyr = np.empty_like(orig_xyr)
# -> 3262         new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3263
#    3264         # Transform the point coordinates back to data coordinates
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in beeswarm(self, orig_xyr)
#    3307
#    3308             # Find the first candidate that does not overlap any neighbors
# -> 3309             new_xyr_i = self.first_non_overlapping_candidate(candidates, neighbors)
#    3310
#    3311             # Place it into the swarm
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in first_non_overlapping_candidate(self, candidates, neighbors)
#    3362             dx = neighbors_x - x_i
#    3363             dy = neighbors_y - y_i
# -> 3364             sq_distances = np.square(dx) + np.square(dy)
#    3365
#    3366             sep_needed = np.square(neighbors_r + r_i)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7b96b2710280> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340                 )
#    2341                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342                     self.figure.draw(renderer)
#    2343
#    2344             if bbox_inches:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in draw(points, renderer, center)
#     563                 def draw(points, renderer, *, center=center):
#     564
# --> 565                     beeswarm(points, center)
#     566
#     567                     if self.orient == "y":
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __call__(self, points, center)
#    3260         # Adjust points along the categorical axis to prevent overlaps
#    3261         new_xyr = np.empty_like(orig_xyr)
# -> 3262         new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3263
#    3264         # Transform the point coordinates back to data coordinates
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in beeswarm(self, orig_xyr)
#    3296             # Find the points in the swarm that could possibly
#    3297             # overlap with the point we are currently placing
# -> 3298             neighbors = self.could_overlap(xyr_i, swarm)
#    3299
#    3300             # Find positions that would be valid individually
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in could_overlap(self, xyr_i, swarm)
#    3321         neighbors = []
#    3322         for xyr_j in reversed(swarm):
# -> 3323             _, y_j, r_j = xyr_j
#    3324             if (y_i - y_j) < (r_i + r_j):
#    3325                 neighbors.append(xyr_j)
#
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3264             # attempt to apply the heuristic to avoid constructing a full mask
#    3265             mout = nomask
# -> 3266             scalar_expected = _scalar_heuristic(self.data, dout)
#    3267             if scalar_expected is None:
#    3268                 # heuristics have failed
#
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py in _get_data(self)
#    3690         return self._baseclass
#    3691
# -> 3692     def _get_data(self):
#    3693         """
#    3694         Returns the underlying data, as a view of the masked array.
#
# KeyboardInterrupt:

# %% [markdown]
# Using a swamplot creates a graph displaying the distribution of a numerical group for each group in a categorical group.

# %%
# Using a Stripplot
sns.stripplot(df, x='tree_depth', y='id', hue='status')
# Out:
# <Axes: xlabel='tree_depth', ylabel='id'>

# %% [markdown]
# Using a stripplot creates a graph showcasing the same thing as a swarmplot, but using different items within the graph.

# %% [markdown]
# From the two plots above, we are able to compare the single-feature plots (ex. violin) in order to see both the distinct points and underlying distributions of the data.

# %% [markdown]
# **Section #4: Summarize - Taylor**

# %% [markdown]
# Using df.shape, df.info(), and df.describe() we are able to see important information like dimensions, names in the dataframe, types of features in the dataframe, and summary stastics. These are important tools due to the large amount of data being used.

# %%
# Shape
df.shape
# Out:
# (533987, 41)

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533987 entries, 0 to 533986
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   datedim                   533987 non-null  object
#  1   id                        533987 non-null  int64
#  2   id_parent                 533987 non-null  int64
#  3   id_path                   533987 non-null  object
#  4   tree_depth                533987 non-null  int64
#  5   tree                      533987 non-null  object
#  6   part_number               533987 non-null  object
#  7   serial_number             533987 non-null  object
#  8   location_name             533987 non-null  object
#  9   original_ip_owner         533987 non-null  object
#  10  current_ip_owner          533987 non-null  object
#  11  operational_nomenclature  533987 non-null  object
#  12  russian_name              532677 non-null  object
#  13  english_name              533987 non-null  object
#  14  barcode                   505396 non-null  object
#  15  quantity                  533987 non-null  int64
#  16  width                     405297 non-null  float64
#  17  height                    513183 non-null  float64
#  18  length                    425934 non-null  float64
#  19  diameter                  128370 non-null  float64
#  20  calculated_volume         528344 non-null  float64
#  21  stwg_ovrrd_vol            0 non-null       float64
#  22  children_volume           21168 non-null   float64
#  23  stwg_ovrrd_chldrn_vol     0 non-null       float64
#  24  ovrrd_notes               0 non-null       float64
#  25  volume_notes              533987 non-null  object
#  26  expire_date               122196 non-null  object
#  27  launch                    367878 non-null  object
#  28  type                      528058 non-null  object
#  29  hazard                    90404 non-null   object
#  30  state                     518053 non-null  object
#  31  status                    533889 non-null  object
#  32  is_container              533987 non-null  int64
#  33  is_moveable               533987 non-null  int64
#  34  system                    529006 non-null  object
#  35  subsystem                 215048 non-null  object
#  36  action_date               533987 non-null  object
#  37  move_date                 533987 non-null  object
#  38  fill_status               27723 non-null   object
#  39  categoryID                533987 non-null  int64
#  40  category_name             533987 non-null  object
# dtypes: float64(9), int64(7), object(25)
# memory usage: 167.0+ MB

# %%
# Describe
df.describe(include='all')
# Out:
#                datedim             id      id_parent  \
# count           533987  533987.000000  533987.000000
# unique             551            NaN            NaN
# top     4/13/2023 9:01            NaN            NaN
# freq              1338            NaN            NaN
# mean               NaN  432533.402328  240574.309908
# std                NaN   59353.511938  194811.375707
# min                NaN    2901.000000     116.000000
# 25%                NaN  422083.000000   53826.000000
# 50%                NaN  448202.000000  169937.000000
# 75%                NaN  470723.000000  447191.000000
# max                NaN  502118.000000  500728.000000
#
#                            id_path     tree_depth              tree  \
# count                       533987  533987.000000            533987
# unique                       10555            NaN                 1
# top     /0/101/276/277/295/364171/            NaN  Storage Location
# freq                           550            NaN            533987
# mean                           NaN       5.270156               NaN
# std                            NaN       0.975596               NaN
# min                            NaN       3.000000               NaN
# 25%                            NaN       5.000000               NaN
# 50%                            NaN       5.000000               NaN
# 75%                            NaN       6.000000               NaN
# max                            NaN      10.000000               NaN
#
#             part_number serial_number               location_name  \
# count            533987        533987                      533987
# unique                9          2523                         365
# top     SEG48102042-901          1180  PMM1_Endcone_Trash Area_CT
# freq             284036          1569                      105871
# mean                NaN           NaN                         NaN
# std                 NaN           NaN                         NaN
# min                 NaN           NaN                         NaN
# 25%                 NaN           NaN                         NaN
# 50%                 NaN           NaN                         NaN
# 75%                 NaN           NaN                         NaN
# max                 NaN           NaN                         NaN
#
#        original_ip_owner  ...  status is_container is_moveable       system  \
# count             533987  ...  533889     533987.0    533987.0       529006
# unique                 2  ...       3          NaN         NaN            6
# top                 NASA  ...  Stowed          NaN         NaN  Food Supply
# freq              410589  ...  353591          NaN         NaN       281656
# mean                 NaN  ...     NaN          1.0         1.0          NaN
# std                  NaN  ...     NaN          0.0         0.0          NaN
# min                  NaN  ...     NaN          1.0         1.0          NaN
# 25%                  NaN  ...     NaN          1.0         1.0          NaN
# 50%                  NaN  ...     NaN          1.0         1.0          NaN
# 75%                  NaN  ...     NaN          1.0         1.0          NaN
# max                  NaN  ...     NaN          1.0         1.0          NaN
#
#        subsystem      action_date        move_date  fill_status  \
# count     215048           533987           533987        27723
# unique         3             3798             3482            2
# top          WHC  11/7/2022 22:48  9/21/2022 18:50        EMPTY
# freq      127552            12751            10531        26971
# mean         NaN              NaN              NaN          NaN
# std          NaN              NaN              NaN          NaN
# min          NaN              NaN              NaN          NaN
# 25%          NaN              NaN              NaN          NaN
# 50%          NaN              NaN              NaN          NaN
# 75%          NaN              NaN              NaN          NaN
# max          NaN              NaN              NaN          NaN
#
#            categoryID  category_name
# count   533987.000000         533987
# unique            NaN              8
# top               NaN        Food-US
# freq              NaN         159306
# mean         4.930420            NaN
# std          1.573899            NaN
# min          1.000000            NaN
# 25%          3.000000            NaN
# 50%          6.000000            NaN
# 75%          6.000000            NaN
# max          7.000000            NaN
#
# [11 rows x 41 columns]

# %% [markdown]
# From the above functions, we now have a snapshot of all of the data that we can use. This makes understanding the data easier and quicker.

# %% [markdown]
# **Section #5: Visualize - Ralph/Taylor/Caden**

# %% [markdown]
# The hist() function returns a histogram chart for every column in a dataframe unless the columns argument is provided. In this case we used tree_depth, calculated_volume, children_volume, and cetegoryID as they provided the most useful data as displayed in the chart.

# %%
# Histogram
df.hist(column=['tree_depth', 'calculated_volume', 'children_volume', 'categoryID'], figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'tree_depth'}>,
#         <Axes: title={'center': 'calculated_volume'}>],
#        [<Axes: title={'center': 'children_volume'}>,
#         <Axes: title={'center': 'categoryID'}>]], dtype=object)

# %%
#Boxplot
df.boxplot(column=['tree_depth', 'calculated_volume', 'children_volume', 'categoryID'], figsize=(16, 6))
# Out:
# <Axes: >

# %%
# Convert the 'datedim' column to datetime if it's not already in datetime format
df['datedim'] = pd.to_datetime(df['datedim'])

# Select only numerical columns for the pairplot
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Create the pairplot
sns.pairplot(df[numerical_columns])

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8ba8430cf01c> in <cell line: 11>()
#       9
#      10 # Show the plot
# ---> 11 plt.show()
#
# NameError: name 'plt' is not defined
# Error in callback <function _draw_all_if_interactive at 0x7b96b2711000> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#    2083
#    2084     @property
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py in draw(self, renderer)
#     970     def draw(self, renderer):
#     971         self.set_sizes(self._sizes, self.figure.dpi)
# --> 972         super().draw(renderer)
#     973
#     974
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py in draw(self, renderer)
#     403             gc.set_antialiased(self._antialiaseds[0])
#     404             gc.set_url(self._urls[0])
# --> 405             renderer.draw_markers(
#     406                 gc, paths[0], combined_transform.frozen(),
#     407                 mpath.Path(offsets), offset_trf, tuple(facecolors[0]))
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7b96b2710280> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340                 )
#    2341                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342                     self.figure.draw(renderer)
#    2343
#    2344             if bbox_inches:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1381
#    1382         # Shift label away from axes to avoid overlapping ticklabels.
# -> 1383         self._update_label_position(renderer)
#    1384         self.label.draw(renderer)
#    1385
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2308             try:
#    2309                 spine = self.axes.spines['bottom']
# -> 2310                 spinebbox = spine.get_window_extent()
#    2311             except KeyError:
#    2312                 # use Axes if spine doesn't exist
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1260         the axes.  Return the list of ticks that will be drawn.
#    1261         """
# -> 1262         major_locs = self.get_majorticklocs()
#    1263         major_labels = self.major.formatter.format_ticks(major_locs)
#    1264         major_ticks = self.get_major_ticks(len(major_locs))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1482     def get_majorticklocs(self):
#    1483         """Return this Axis' major tick locations in data coordinates."""
# -> 1484         return self.major.locator()
#    1485
#    1486     def get_minorticklocs(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in __call__(self)
#    2134     def __call__(self):
#    2135         vmin, vmax = self.axis.get_view_interval()
# -> 2136         return self.tick_values(vmin, vmax)
#    2137
#    2138     def tick_values(self, vmin, vmax):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2142         vmin, vmax = mtransforms.nonsingular(
#    2143             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144         locs = self._raw_ticks(vmin, vmax)
#    2145
#    2146         prune = self._prune
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2081         if self._nbins == 'auto':
#    2082             if self.axis is not None:
# -> 2083                 nbins = np.clip(self.axis.get_tick_space(),
#    2084                                 max(1, self._min_n_ticks - 1), 9)
#    2085             else:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_tick_space(self)
#    2472         self.stale = True
#    2473
# -> 2474     def get_tick_space(self):
#    2475         ends = mtransforms.Bbox.unit().transformed(
#    2476             self.axes.transAxes - self.figure.dpi_scale_trans)
#
# KeyboardInterrupt:

# %% [markdown]
# The histogram results show us the frequencies for tree_depth, calculate_volume, children_volume, and category ID values. From this we see how certain values are repeated. The box plots provides insight into outliers and the overall range of data values for each category.

# %% [markdown]
#  **Section #6: Outliers - Omokunle/Alexander**
# ##### Dealing with outliers
# ##### Tukey's fences and z-scores are two simple ways to find outliers. Both strategies assume that outliers will be on the far edge of the feature distribution. Outliers, like missing data, should be studied to determine their potential causes and the implications for the study.
#
# - Tukey's Fences
#   Often used to determine outliers in box plots, calculates the interquartile range, IQR = Q3 − Q1 for a feature.
#   Classify all points that fall 1.5 IQR above Q3 or 1.5 IQR below Q1 as outliers.
# - z-scores
#   Calculate the z-score, z=(value-mean)/(Standard Deviation) for each value.
#   Classify all points that have a z-score of |z| > 3 as outliers.

# %% [markdown]
# ##### Python code below creates data visualizations and calculates z-scores for features in the Barrios-ASU - ISS Consumables Data Package dataset.

# %%
# Import packages and dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Box plot of bill length by species
p = sns.boxplot(data=df, x='tree_depth', y='tree')
p.set_xlabel('tree', fontsize=14)
p.set_ylabel('tree_depth', fontsize=14)
plt.show()

# %%
# Calculate z-scores of tree depth for each tree
treeGroups = df.groupby('tree')

# z-score = a measure of how far an observation is from the mean
# z-score = (obs-mean)/SD
df[''] = treeGroups['tree_depth'].transform(
    lambda x: (x - x.mean()) / x.std()
)

# Sort the result by the largest absolute z-score
df.sort_values(by=['tree_depth'], ascending=False, key=lambda x: abs(x)).head(6)
# Out:
#                    datedim      id  id_parent  \
# 456571 2023-06-29 09:04:00  407290     448332
# 455531 2023-06-28 09:04:00  407290     448332
# 457612 2023-06-30 09:03:00  407290     448332
# 453456 2023-06-26 09:03:00  407290     448332
# 454492 2023-06-27 09:04:00  407290     448332
# 451378 2023-06-24 09:03:00  407290     448332
#
#                                                   id_path  tree_depth  \
# 456571  /0/490393/490398/490429/490436/483277/454202/4...          10
# 455531  /0/490393/490398/490429/490436/483277/454202/4...          10
# 457612  /0/490393/490398/490429/490436/483277/454202/4...          10
# 453456  /0/490393/490398/490429/490436/483277/454202/4...          10
# 454492  /0/490393/490398/490429/490436/483277/454202/4...          10
# 451378  /0/490393/490398/490429/490436/483277/454202/4...          10
#
#                     tree     part_number serial_number location_name  \
# 456571  Storage Location  10182.5514.000       1805353    DRA28_MP22
# 455531  Storage Location  10182.5514.000       1805353    DRA28_MP22
# 457612  Storage Location  10182.5514.000       1805353    DRA28_MP22
# 453456  Storage Location  10182.5514.000       1805353    DRA28_MP22
# 454492  Storage Location  10182.5514.000       1805353    DRA28_MP22
# 451378  Storage Location  10182.5514.000       1805353    DRA28_MP22
#
#        original_ip_owner  ... is_container is_moveable system subsystem  \
# 456571              NASA  ...            1           1  ECLSS       WHC
# 455531              NASA  ...            1           1  ECLSS       WHC
# 457612              NASA  ...            1           1  ECLSS       WHC
# 453456              NASA  ...            1           1  ECLSS       WHC
# 454492              NASA  ...            1           1  ECLSS       WHC
# 451378              NASA  ...            1           1  ECLSS       WHC
#
#            action_date        move_date  fill_status  categoryID  \
# 456571  3/2/2023 12:10  4/19/2022 21:58          NaN           5
# 455531  3/2/2023 12:10  4/19/2022 21:58          NaN           5
# 457612  3/2/2023 12:10  4/19/2022 21:58          NaN           5
# 453456  3/2/2023 12:10  4/19/2022 21:58          NaN           5
# 454492  3/2/2023 12:10  4/19/2022 21:58          NaN           5
# 451378  3/2/2023 12:10  4/19/2022 21:58          NaN           5
#
#          category_name
# 456571  Filter Inserts  4.848158
# 455531  Filter Inserts  4.848158
# 457612  Filter Inserts  4.848158
# 453456  Filter Inserts  4.848158
# 454492  Filter Inserts  4.848158
# 451378  Filter Inserts  4.848158
#
# [6 rows x 42 columns]

# %%
# Create a subset containing only storage location trees
storageLocation = df[df['tree'] == 'Storage Location']

plt.rcParams["figure.figsize"] = (10, 5)

p = sns.lmplot(
    data=storageLocation,
    x='quantity',
    y='tree_depth',
    scatter_kws={'alpha': 0.3, 'color': '#10a60e'},
    ci=False,
)
p.set_axis_labels('quantity', 'tree_depth', fontsize=14)
plt.plot(59.6, 17, 'go')
plt.text(59.6 + 0.5, 17, 'A', fontsize=16)
plt.plot(44.4, 17.3, 'go')
plt.text(44.4 + 0.5, 17.3, 'B', fontsize=16)
plt.plot(40.9, 13.7, 'go')
plt.text(40.9 - 1.5, 13.7, 'C', fontsize=16)
# Out:
# Text(39.4, 13.7, 'C')

# %% [markdown]
# From our above boxplots, we are able to see several tree_depth and tree_depth outliers. This allows us to make analytical decision based on these outliers and whether or not they need to be cleaned when presented as a refined dataset or visualization.
